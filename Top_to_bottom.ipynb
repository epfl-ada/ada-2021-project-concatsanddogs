# %% [markdown]
# ### Header
# Author : Amina Matt
# Date created : 30.11.2021
# Date last modified : 30.11.2021
# Description : Top to bottom approach to select femonationalist quotes. Define keywords/patterns critera to select femonationalistic quotes from already selected quotes

# %% [markdown]
# ### Load dataframe of selected quotes

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
PATH = 'generated_data/'
pd.options.display.max_colwidth = 350

# %%
# Concatenate into one dataframes the dataframes from each pickle file. 
dataframesNames = ('QOI_2015_DF','QOI_2016_DF','QOI_2017_DF','QOI_2018_DF','QOI_2019_DF','QOI_2020_DF')
df = pd.concat([pd.read_pickle(PATH+ fp +'.pkl') for fp in dataframesNames], ignore_index=True)

# %%
df.head()
# Out:
#              quoteID  \
# 0  2015-03-09-004706
# 1  2015-04-24-025718
# 2  2015-07-16-044620
# 3  2015-09-11-052815
# 4  2015-04-23-037713
#
#                                                                                                                                                                                                                                                                                                                                                        quotation  \
# 0                                                                                                                                                   Anything less than women winning 50 per cent of new seats will be a loss not only for a progressive city's progress towards true gender equality but it would also be a loss for good governance in the ACT.
# ...

# %%
print(f'The dataframe has {len(df)} entries')
# Out:
# The dataframe has 87161 entries

# %%
df.head()['quotation']
# Out:
# 0                                                                                                                                                     Anything less than women winning 50 per cent of new seats will be a loss not only for a progressive city's progress towards true gender equality but it would also be a loss for good governance in the ACT.
# 1                                      I'd like to congratulate all the winners and finalists on their success. They have demonstrated clear leadership by moving women's progression from a `diversity' initiative to a core business priority. Achieving gender equality is only possible when men and women work together at every level, creating real change.
# ...

# %% [markdown]
# ## Theme 1 : Muslim women and feminism

# %%
keywords_sublist = ('Muslim women')
#Select quotes containing specific keywords
def add_column(dataframe, keywords_sublist):
    sub_df = df[df['quotation'].str.contains(keywords_sublist,case=False)]
    return sub_df

# %%
df_theme1 = select_theme_1(df,keywords_sublist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3v/cd3_rvz10bd1jd08x0c03tpr0000gt/T/ipykernel_94009/11184589.py in <module>
# ----> 1 df_theme1 = select_theme_1(df,keywords_sublist)
#
# NameError: name 'select_theme_1' is not defined

# %%
len(df_theme1)

# %%
#Tested : womens rights, vulnerable, saving,hijab,niqab,oppressed
sub = df_theme1[df_theme1['quotation'].str.contains('oppressed',case=False)]

# %%
len(sub)

# %%
sub

# %% [markdown]
# ## Theme 2 : Women's right and immigration

# %%
keywords_sublist = ('women\'s rights')
#Select quotes containing specific keywords
tmp = df[df['quotation'].str.contains(keywords_sublist,case=False)]
final = tmp[tmp['quotation'].str.contains('immigration',case=False)]

# %%
len(final)

# %%
final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3v/cd3_rvz10bd1jd08x0c03tpr0000gt/T/ipykernel_94009/1875444114.py in <module>
# ----> 1 final
#
# NameError: name 'final' is not defined

# %% [markdown]
# ### Theme 3 : Western more advanced on women rights
# ### Theme 4 : Muslim men as threats

# %%
keywords_sublist = ('muslim men')
#Select quotes containing specific keywords
tmp = df[df['quotation'].str.contains(keywords_sublist,case=False)]
final = tmp[tmp['quotation'].str.contains('women',case=False)]

# %%
final.head()
# Out:
#                 quoteID  \
# 770   2015-11-08-060223
# 3687  2015-11-30-072102
# 4808  2015-12-22-082850
# 5727  2015-02-03-018919
# 6327  2015-12-08-059355
#
#                                                                                                                                                                                               quotation  \
# 770                                This case is a very good example of how Muslim men abuse triple talaq and also how Muslim women often fail to get justice because there is no codified personal law,
# 3687                                                             Muslim men rape non-Muslim women (and girls) in disproportionately high numbers in countries with growing Muslim minority populations.
# 4808                                                                                                              These ISIS clowns murder more Muslim men and rape more Muslim women than anyone else,
# ...

# %% [markdown]
# ## TWO CATEGORIES

# %%
KEYWORDS_WAGES_EQUALITY =(
    'equal pay',
    'Equal wages',
     'men pay',
     'pay percentage',
)


KEYWORDS_EQUALITY = (
'Equal opportunities',
'Equal rights',
'Equal status',
'Gender equality',
'gender equity',
'gender gap',
 'percentage men',
 'women\'s right',
 'Women empowerment',
 'Women emancipation',
  'Gender discrimination',
 'Men and women',
 'women and men',
 'women oppression',
 'struggle of girls',
 'struggle of women',
 'war against women',
 'oppression of girls',
 'oppression of women',
 'women oppression',
 "women's opression",
 'liberate women',
 'Male oppression',
 'Female oppression',
 'Patriarchal culture',
 'gender equality',
 'women girls',
 'girls women',
 'rates women',
 'women according',
 'share women',
 'women movement',
 'see women',
 'gender stereotypes',
 'women representation',
 'sex discrimination',
 'women rights',
 'woman time',
 'based gender',
 'entirely female',
     'women immigration',
 "women's participation",)
KEYWORDS_REPRODUCTION_WORK = (
'Exploitation of women',
 'child care',
)
KEYWORDS_SEXUAL = (
'Sexual harrasment',
'abuse of women',
'sexual harassment',
'women victim',
'gender-based violence',
)
KEYWORDS_TRANS = ('trans ')
KEYWORDS_ABORTION = ('abortion')
KEYWORDS_INDIGENEOUS = ('Indigenous')
KEYWORDS_REPRESENTATION = ('female mayors','female candidates')
KEYWORDS_FEMONAT = ('Western women',
 'non-western woman',
 'Muslim women',
 'Muslim woman',
 'niqab ban',
 'religious oppression')

# %%
#ADD column with KEYWORDS
df['subtopic'] = np.where(df.quotation.str.contains('|'.join(KEYWORDS_FEMONAT)), "islam",
                 np.where(df.quotation.str.contains('|'.join(KEYWORDS_REPRESENTATION)), "representation",
                 np.where(df.quotation.str.contains(KEYWORDS_INDIGENEOUS), "indigenous",
                 np.where(df.quotation.str.contains(KEYWORDS_ABORTION), "abortion",
                 np.where(df.quotation.str.contains(KEYWORDS_TRANS), "trans",    
                 np.where(df.quotation.str.contains('|'.join(KEYWORDS_SEXUAL)), "sexual", 
                 np.where(df.quotation.str.contains('|'.join(KEYWORDS_WAGES_EQUALITY)), "wages equality",
                 np.where(df.quotation.str.contains('|'.join(KEYWORDS_REPRODUCTION_WORK)), "reproductive work",  
                 np.where(df.quotation.str.contains('|'.join(KEYWORDS_EQUALITY)),"equality","other")))))))))

# %%
def add_subtopic(df):
    df['subtopic'] = np.where(df.quotation.str.contains('|'.join(KEYWORDS_FEMONAT)), "islam",
                 np.where(df.quotation.str.contains('|'.join(KEYWORDS_REPRESENTATION)), "representation",
                 np.where(df.quotation.str.contains(KEYWORDS_INDIGENEOUS), "indigenous",
                 np.where(df.quotation.str.contains(KEYWORDS_ABORTION), "abortion",
                 np.where(df.quotation.str.contains(KEYWORDS_TRANS), "trans",    
                 np.where(df.quotation.str.contains('|'.join(KEYWORDS_SEXUAL)), "sexual", 
                 np.where(df.quotation.str.contains('|'.join(KEYWORDS_WAGES_EQUALITY)), "wages equality",
                 np.where(df.quotation.str.contains('|'.join(KEYWORDS_REPRODUCTION_WORK)), "reproductive work",  
                 np.where(df.quotation.str.contains('|'.join(KEYWORDS_EQUALITY)),"equality","other")))))))))
    return df

# %%
df.head(100)[['quotation','subtopic']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                         quotation  \
# 0                                                                                                                                                    Anything less than women winning 50 per cent of new seats will be a loss not only for a progressive city's progress towards true gender equality but it would also be a loss for good governance in the ACT.
# ...

# %%
plt = df['subtopic'].value_counts().sort_index().plot.bar(x='Target Value', y='Number of Occurrences').get_figure()
plt.tight_layout()
fig.savefig("all_subtopics_barplot.png")

# %%
plt.tight_layout()
fig.savefig('all_subtopics_barplot.ong')

# %% [markdown]
# # Sentiment

# %%
#Vader
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
quote = df['quotation'].iloc[0]
analyzer = SentimentIntensityAnalyzer()
vs = analyzer.polarity_scores(df['quotation'].loc[1])
df['sentiment'] = df['quotation'].apply(lambda x : analyzer.polarity_scores(x)['compound'])

# %%
df['sentiment'].hist(bins=40, figsize = [8,5])
plt.show()

# %%
neg = df[df['sentiment']< 0]
pos = df[df['sentiment'] <= 0]
tot = len(df)
neg_per = len(neg)/tot * 100
pos_per = len(pos)/tot * 100 
neg_per
pos_per
# Out:
# 52.27796835740756

# %% [markdown]
# ## Per year

# %%
# take a threshold and separate the data in two : 
# threshold choice currently partly arbitrary
df_positive = df.query('sentiment > 0.25')
df_negative = df.query('sentiment < -0.25')
df_neutral  = df.query('sentiment > -0.25').query('sentiment < 0.25')

df_positive['date']
# Out:
# 0       2015-03-09 12:30:00
# 1       2015-04-24 15:33:00
# 2       2015-07-16 16:41:07
# 3       2015-09-11 14:17:08
# 7       2015-04-20 11:20:21
#                 ...
# 87155   2020-03-22 15:54:00
# 87157   2020-01-01 21:50:26
# 87158   2020-01-19 00:00:00
# 87159   2020-03-09 11:00:31
# 87160   2020-01-28 02:08:54
# Name: date, Length: 36008, dtype: datetime64[ns]

# %%
#function splitting years

def split_years(dt):
    dt['year'] = dt['date'].dt.year
    return [dt[dt['year'] == y] for y in dt['year'].unique()]

df_positive_per_year = split_years(df_positive)
df_negative_per_year = split_years(df_negative)
df_neutral_per_year = split_years(df_neutral)
# Out:
# /var/folders/3v/cd3_rvz10bd1jd08x0c03tpr0000gt/T/ipykernel_4114/1067200056.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt['year'] = dt['date'].dt.year

# %%
len(df_positive_per_year[0])
# Out:
# 4923

# %%
def percentage_df(df_pos,df_neg,df_neu):
    per_year_df = pd.DataFrame(columns=['year','positive percentage','pos ci_min','pos ci_max','negative percentage','neg ci_min','neg ci_max','neutral percentage','neu ci_min','neu ci_max'])
    for i in range(6):
        len_pos = len(df_pos[i]) 
        len_neg = len(df_neg[i])
        len_neu = len(df_neu[i])
        tot = len_neg + len_pos + len_neu
        per_year_df = per_year_df.append({
            'year':(df_pos[i]['year'].unique())[0],
            'positive percentage':len_pos/tot *100,
             'negative percentage':len_neg/tot *100,
             'neutral percentage':len_neu/tot *100,
            },ignore_index=True)
        
    return per_year_df
per_year_df = percentage_df(df_positive_per_year,df_negative_per_year,df_neutral_per_year)
per_year_df.head()
# Out:
#      year  positive percentage  pos ci_min  pos ci_max  negative percentage  \
# 0  2015.0            50.286006         NaN         NaN            28.018386
# 1  2016.0            46.730545         NaN         NaN            29.962450
# 2  2017.0            37.001470         NaN         NaN            44.307113
# 3  2018.0            37.173388         NaN         NaN            43.656547
# 4  2019.0            44.869658         NaN         NaN            34.573265
#
#    neg ci_min  neg ci_max  neutral percentage  neu ci_min  neu ci_max
# 0         NaN         NaN           21.695608         NaN         NaN
# 1         NaN         NaN           23.307005         NaN         NaN
# 2         NaN         NaN           18.691417         NaN         NaN
# 3         NaN         NaN           19.170065         NaN         NaN
# 4         NaN         NaN           20.557077         NaN         NaN

# %%
ax = per_year_df.plot.bar(x='year', y='positive percentage', rot=0,color = 'Green')
ax = per_year_df.plot.bar(x='year', y='negative percentage', rot=0,color = 'Red')
ax = per_year_df.plot.bar(x='year', y='neutral percentage', rot=0,color = 'Blue')

# %% [markdown]
# #### Bootstrapping

# %%
df_all_boots = pd.DataFrame(columns=['year','positive percentage','negative percentage','neutral percentage'])
# scikit-learn bootstrap
from sklearn.utils import resample
#Choose a number of bootstrap samples to perform 
boot_numbers = 200
#Choose a sample size
n = 150000#10000
#For each bootstrap sample
for i in range(boot_numbers):
    #draw a sample with replacement with the chose size
    # prepare bootstrap sample
    boot = resample(df, replace=True, n_samples = n)
    df_boot_positive = boot.query('sentiment > 0.35')
    df_boot_negative = boot.query('sentiment < -0.35')
    df_boot_neutral  = boot.query('sentiment > -0.35').query('sentiment < 0.35')
    
    
    #categorize per year
    df_positive_per_year = split_years(df_boot_positive)
    df_negative_per_year = split_years(df_boot_negative)
    df_neutral_per_year = split_years(df_boot_neutral)
    df_boot = percentage_df(df_positive_per_year,df_negative_per_year,df_neutral_per_year)
    df_all_boots = df_all_boots.append(df_boot)

df_all_boots.head()
# Out:
# /var/folders/3v/cd3_rvz10bd1jd08x0c03tpr0000gt/T/ipykernel_4114/1067200056.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt['year'] = dt['date'].dt.year
#      year  positive percentage  negative percentage  neutral percentage  \
# 0  2020.0            20.202941            21.679426           58.117633
# 1  2017.0            37.430299            27.104293           35.465408
# 2  2018.0            56.422625            14.921213           28.656162
# 3  2015.0            31.781984            60.994838            7.223178
# 4  2019.0            34.353529            51.592755           14.053716
#
#    pos ci_min  pos ci_max  neg ci_min  neg ci_max  neu ci_min  neu ci_max
# ...

# %%
df_all_boots.head(100)
# Out:
#       year  positive percentage  negative percentage  neutral percentage  \
# 0   2020.0            20.202941            21.679426           58.117633
# 1   2017.0            37.430299            27.104293           35.465408
# 2   2018.0            56.422625            14.921213           28.656162
# 3   2015.0            31.781984            60.994838            7.223178
# 4   2019.0            34.353529            51.592755           14.053716
# ..     ...                  ...                  ...                 ...
# 5   2015.0            69.705357            14.839286           15.455357
# 0   2016.0            22.988460            60.887386           16.124154
# 1   2017.0            59.582223            16.991448           23.426328
# 2   2019.0            28.247996            43.534924           28.217080
# 3   2018.0            53.139653            14.036697           32.823649
#
#     pos ci_min  pos ci_max  neg ci_min  neg ci_max  neu ci_min  neu ci_max
# ...

# %%
years = [2015.0,2016.0,2017.0,2018.0,2019.0,2020.0]
final = pd.DataFrame()
for year in years :
    tmp = per_year_df[per_year_df['year']==year]
    df_year = df_all_boots[df_all_boots['year']==year]
    #ci_minus = (df_year.sort_values(by='positive percentage'))['positive percentage'].iloc[5]
    #ci_plus = df_year.sort_values(by='positive percentage')['positive percentage'].iloc[95]
    stats = df_year.describe()['positive percentage']
    ci_minus = - (1.96 * stats.loc['std']  / np.sqrt(boot_numbers))
    ci_plus =  + (1.96 * stats.loc['std']  / np.sqrt(boot_numbers))
    #print(stats)
    #print( (1.645 * stats.loc['std'] ))
    #print(np.sqrt(boot_numbers))
    tmp['pos ci_min'] = ci_minus
    tmp['pos ci_max'] = ci_plus
    
    #stats = df_year.describe()['negative percentage']
    ci_minus = - (1.96 * stats.loc['std']  / np.sqrt(boot_numbers))
    ci_plus = + (1.96 * stats.loc['std']  / np.sqrt(boot_numbers))
    #ci_minus = (df_year.sort_values(by='negative percentage'))['negative percentage'].iloc[5]
    #ci_plus = df_year.sort_values(by='negative percentage')['negative percentage'].iloc[95]
    tmp['neg ci_min'] = ci_minus
    tmp['neg ci_max'] = ci_plus
   
    #stats = df_year.describe()['neutral percentage']
    ci_minus =  - (1.96 * stats.loc['std']  / np.sqrt(boot_numbers))
    ci_plus =  + (1.96 * stats.loc['std']  / np.sqrt(boot_numbers))
   # ci_minus = (df_year.sort_values(by='neutral percentage'))['neutral percentage'].iloc[5]
   # ci_plus = df_year.sort_values(by='neutral percentage')['neutral percentage'].iloc[95]
    tmp['neu ci_min'] = ci_minus
    tmp['neu ci_max'] = ci_plus
    final = final.append(tmp)
# Out:
# /var/folders/3v/cd3_rvz10bd1jd08x0c03tpr0000gt/T/ipykernel_4114/1090057533.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['pos ci_min'] = ci_minus
# /var/folders/3v/cd3_rvz10bd1jd08x0c03tpr0000gt/T/ipykernel_4114/1090057533.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['pos ci_max'] = ci_plus
# /var/folders/3v/cd3_rvz10bd1jd08x0c03tpr0000gt/T/ipykernel_4114/1090057533.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
final
# Out:
#      year  positive percentage  pos ci_min  pos ci_max  negative percentage  \
# 0  2015.0            50.286006   -1.846921    1.846921            28.018386
# 1  2016.0            46.730545   -1.895449    1.895449            29.962450
# 2  2017.0            37.001470   -1.924336    1.924336            44.307113
# 3  2018.0            37.173388   -1.713085    1.713085            43.656547
# 4  2019.0            44.869658   -1.874415    1.874415            34.573265
# 5  2020.0            53.182055   -1.692891    1.692891            28.247261
#
#    neg ci_min  neg ci_max  neutral percentage  neu ci_min  neu ci_max
# 0   -1.846921    1.846921           21.695608   -1.846921    1.846921
# 1   -1.895449    1.895449           23.307005   -1.895449    1.895449
# 2   -1.924336    1.924336           18.691417   -1.924336    1.924336
# 3   -1.713085    1.713085           19.170065   -1.713085    1.713085
# 4   -1.874415    1.874415           20.557077   -1.874415    1.874415
# ...

# %%
final_pos = final[['year','positive percentage']]
final_pos
# Out:
#      year  positive percentage
# 0  2015.0            50.286006
# 1  2016.0            46.730545
# 2  2017.0            37.001470
# 3  2018.0            37.173388
# 4  2019.0            44.869658
# 5  2020.0            53.182055

# %%
err_pos = final['pos ci_max']
err_pos
ax = final_pos.plot.bar(x='year', y='positive percentage', rot=0,color = 'Green',yerr=err_pos)
# Out:
# /opt/anaconda3/envs/ada/lib/python3.8/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
final['year']=final['year'].apply(lambda x: f'{x:.0f}')

# %%
from matplotlib.ticker import PercentFormatter

# Just write the name of the font
mpl.rcParams['font.sans-serif'] = 'Lato'
print(mpl.rcParams['font.sans-serif'])
plt.rcParams['font.size'] = 14
plt.rcParams["figure.figsize"] = (16,3)

fig, axes = plt.subplots(nrows=1, ncols=3)

ax1 = final.plot.bar(ax=axes[0],x='year', y='positive percentage', rot=15,color = '#4EA692',yerr=[final['pos ci_max']],legend='test',xlabel = 'Year',ylim=(0,60))
ax2 = final.plot.bar(ax=axes[1],x='year', y='negative percentage', rot=15,color = '#FF3A20',yerr=[final['neg ci_max']],xlabel = 'Year',ylim=(0,60))
ax3 = final.plot.bar(ax=axes[2],x='year', y='neutral percentage', rot=15,color = '#FFB60A',yerr=[final['neu ci_max']],xlabel = 'Year',ylim=(0,60))
ax1.legend(["positive"]);
ax2.legend(["negative"]);
ax3.legend(["neutral"]);
ax1.yaxis.set_major_formatter(PercentFormatter())
ax2.yaxis.set_major_formatter(PercentFormatter())
ax3.yaxis.set_major_formatter(PercentFormatter())


plt.savefig('byyear_sentiment_barplot.png')
# Out:
# ['Lato']

# %% [markdown]
# ## Examples for different subtopic

# %%
df_positive_per_year[0]
# Out:
#                 quoteID  \
# 0     2015-03-09-004706
# 1     2015-04-24-025718
# 2     2015-07-16-044620
# 3     2015-09-11-052815
# 7     2015-04-20-053254
# ...                 ...
# 9865  2015-09-06-066656
# 9866  2015-09-28-024178
# 9870  2015-03-03-070438
# 9872  2015-02-23-005694
# 9874  2015-06-06-016212
#
#                                                                                                                                                                                                                                                                                                                                                           quotation  \
# ...

# %% [markdown]
# ### Trans

# %%
df[df['subtopic']=='trans'].head()[['quotation','subtopic']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                           quotation  \
# 98                                                                                                                                                                        We're very excited to do work with these amazing women and men and to see the amazing talent LA has to offer. At Apple Model Management, you're a model first, and a trans person second,
# ...

# %%
df_trans = df[df['subtopic']=='trans']
df_trans['sentiment'].hist(bins=40, figsize = [8,5])
plt.show()

# %% [markdown]
# ### Islam

# %%
df[df['subtopic']=='islam'].head()[['quotation','subtopic']]
# Out:
#                                                                                                                                                                                                           quotation  \
# 7                         The apex court has upheld an earlier verdict of a family court granting maintenance allowance to Muslim women even after the `iddat' period (three months and 10 days after the divorce),
# 59  You can regurgitate Fox News as much as you want to get some book sales, but that's not doing anything to contribute to the progression of Muslim women's rights or our place in society or anything like that,
# 70                                                    It's great to see everyone mixing together because people say Muslim women just stay at home and stuff like that. Here you can see they've proven them wrong.
# ...

# %%
df_islam = df[df['subtopic']=='islam']
df_islam['sentiment'].hist(bins=40, figsize = [8,5])
plt.show()

# %% [markdown]
# #### Femonationalist

# %%
neg_islam = df_islam[df_islam['sentiment']< 0]

neg_islam[['quotation','sentiment']].head(50).sort_values(by='sentiment')
# Out:
#                                                                                                                                                                                                                                                                                                                                                           quotation  \
# 3749  Being a Muslim woman in America today is very exhausting. Every once in a while when a horrific event happens, Muslim women face horrible backlash. It seems like it's become a roller coaster ride. First the tensions are high then they slow down and come back again and every single time, Muslim women are being forced to apologize, condemn and re...
# ...

# %% [markdown]
# ### Indigenous

# %%
df[df['subtopic']=='indigenous'].head()[['quotation','subtopic']]
# Out:
#                                                                                                                                                                                                          quotation  \
# 21     There's a correlation between the environment and the way that Indigenous people are treated and how the aggression to our lands parallels to our bodies as Indigenous women. So, it's all linked together,
# 102                                                                                                                My grandmother was one of the missing and murdered Indigenous women and I want to remember her,
# 140  Indigenous women and girls in Canada have been murdered or have gone missing at a rate four times higher than the rate of representation of indigenous women in the Canadian population which is 4.3 percent,
# ...

# %% [markdown]
# # TIME EXPLORATION

# %%
df[df['subtopic']=='indigenous'].head()[['quotation','subtopic']]
# Out:
#                                              quotation    subtopic
# 21   There's a correlation between the environment ...  indigenous
# 102  My grandmother was one of the missing and murd...  indigenous
# 140  Indigenous women and girls in Canada have been...  indigenous
# 217  The IACHR has concluded that the response of g...  indigenous
# 247  This event provides an excellent opportunity t...  indigenous
